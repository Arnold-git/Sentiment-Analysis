# %%
def pretty_review_and_label(i):
    print(label[i] + "\t:t" + reviews[i][:80] + "...")
g = open('reviews.txt', 'r')
reviews = list(map(lambda x:x[:-1], g.readlines()))
g.close()

g = open('labels.txt','r')
labels = list(map(lambda x:x[:-1].upper(),g.readlines()))
g.close
# Out:
# <function TextIOWrapper.close()>

# %%
len(reviews)
# Out:
# 25000

# %%
a = 'Thsi is a practise test'

a.split(" ")
# Out:
# ['Thsi', 'is', 'a', 'practise', 'test']

# %%
b = 'practise test two'

b.split(" ")
# Out:
# ['practise', 'test', 'two']

# %%
from collections import Counter
import numpy as np

# %%
positive_counts = Counter()
negative_counts = Counter()
total_counts = Counter()

# %%
for i in range(len(reviews)):
    if (labels[i] == 'POSITIVE'):
        for word in reviews[i].split(" "):
            positive_counts[word] += 1
            total_counts[word] += 1
    else:
        for word in reviews[i].split(" "):
            negative_counts[word] += 1
            total_counts[word] += 1

# %%
positive_counts.most_common(40)
# Out:
# [('', 550468),
#  ('the', 173324),
#  ('.', 159654),
#  ('and', 89722),
#  ('a', 83688),
#  ('of', 76855),
#  ('to', 66746),
#  ('is', 57245),
#  ('in', 50215),
#  ('br', 49235),
#  ('it', 48025),
#  ('i', 40743),
#  ('that', 35630),
#  ('this', 35080),
#  ('s', 33815),
#  ('as', 26308),
#  ('with', 23247),
#  ('for', 22416),
#  ('was', 21917),
#  ('film', 20937),
#  ('but', 20822),
#  ('movie', 19074),
#  ('his', 17227),
#  ('on', 17008),
#  ('you', 16681),
#  ('he', 16282),
#  ('are', 14807),
#  ('not', 14272),
#  ('t', 13720),
#  ('one', 13655),
#  ('have', 12587),
#  ('be', 12416),
#  ('by', 11997),
#  ('all', 11942),
#  ('who', 11464),
#  ('an', 11294),
#  ('at', 11234),
#  ('from', 10767),
#  ('her', 10474),
#  ('they', 9895)]

# %%
negative_counts.most_common(40)
# Out:
# [('', 561462),
#  ('.', 167538),
#  ('the', 163389),
#  ('a', 79321),
#  ('and', 74385),
#  ('of', 69009),
#  ('to', 68974),
#  ('br', 52637),
#  ('is', 50083),
#  ('it', 48327),
#  ('i', 46880),
#  ('in', 43753),
#  ('this', 40920),
#  ('that', 37615),
#  ('s', 31546),
#  ('was', 26291),
#  ('movie', 24965),
#  ('for', 21927),
#  ('but', 21781),
#  ('with', 20878),
#  ('as', 20625),
#  ('t', 20361),
#  ('film', 19218),
#  ('you', 17549),
#  ('on', 17192),
#  ('not', 16354),
#  ('have', 15144),
#  ('are', 14623),
#  ('be', 14541),
#  ('he', 13856),
#  ('one', 13134),
#  ('they', 13011),
#  ('at', 12279),
#  ('his', 12147),
#  ('all', 12036),
#  ('so', 11463),
#  ('like', 11238),
#  ('there', 10775),
#  ('just', 10619),
#  ('by', 10549)]

# %%
pos_neg_ratios = Counter()

for word,cnt in list(total_counts.most_common()):
    if (cnt > 100):
        pos_neg_ratio = positive_counts[word] / float(negative_counts[word] + 1)
        pos_neg_ratios[word] = pos_neg_ratio

# %%
print("The pos_nrg_ratio for 'the' = {}".format(pos_neg_ratios['the']))
print("The pos_nrg_ratio for 'amazing' = {}".format(pos_neg_ratios['amazing']))
print("The pos_nrg_ratio for 'terrible' = {}".format(pos_neg_ratios['terrible']))
# Out:
# The pos_nrg_ratio for 'the' = 1.0607993145235326
# The pos_nrg_ratio for 'amazing' = 4.022813688212928
# The pos_nrg_ratio for 'terrible' = 0.17744252873563218

# %%
# This gives  an idea of the words that were used most in the

pos_neg_ratios.most_common()
# Out:
# [('edie', 109.0),
#  ('paulie', 59.0),
#  ('felix', 23.4),
#  ('polanski', 16.833333333333332),
#  ('matthau', 16.555555555555557),
#  ('victoria', 14.6),
#  ('mildred', 13.5),
#  ('gandhi', 12.666666666666666),
#  ('flawless', 11.6),
#  ('superbly', 9.583333333333334),
#  ('perfection', 8.666666666666666),
#  ('astaire', 8.5),
#  ('captures', 7.68),
#  ('voight', 7.615384615384615),
#  ('wonderfully', 7.552631578947368),
#  ('powell', 7.230769230769231),
#  ('brosnan', 7.0625),
#  ('lily', 6.823529411764706),
#  ('bakshi', 6.705882352941177),
#  ('lincoln', 6.695652173913044),
#  ('refreshing', 6.392857142857143),
#  ('breathtaking', 6.3478260869565215),
#  ('bourne', 6.346153846153846),
#  ('lemmon', 6.333333333333333),
#  ('delightful', 6.051282051282051),
#  ('flynn', 6.0476190476190474),
#  ('andrews', 5.909090909090909),
#  ('homer', 5.866666666666666),
#  ('beautifully', 5.828125),
#  ('soccer', 5.8),
#  ('elvira', 5.695652173913044),
#  ('underrated', 5.583333333333333),
# ...

# %%
for word, ratio in pos_neg_ratios.most_common():
    if ratio > 1:
        pos_neg_ratios[word] = np.log(ratio)
    else:
        pos_neg_ratios[word] = -np.log((1 / (ratio + 0.01)))

# %%
pos_neg_ratios.most_common()
# Out:
# [('edie', 4.6913478822291435),
#  ('paulie', 4.07753744390572),
#  ('felix', 3.152736022363656),
#  ('polanski', 2.8233610476132043),
#  ('matthau', 2.80672172860924),
#  ('victoria', 2.681021528714291),
#  ('mildred', 2.6026896854443837),
#  ('gandhi', 2.538973871058276),
#  ('flawless', 2.451005098112319),
#  ('superbly', 2.26002547857525),
#  ('perfection', 2.159484249353372),
#  ('astaire', 2.1400661634962708),
#  ('captures', 2.038619547159581),
#  ('voight', 2.030170492673053),
#  ('wonderfully', 2.0218960560332353),
#  ('powell', 1.978345424808467),
#  ('brosnan', 1.9547990964725592),
#  ('lily', 1.9203768470501485),
#  ('bakshi', 1.9029851043382795),
#  ('lincoln', 1.9014583864844796),
#  ('refreshing', 1.8551812956655511),
#  ('breathtaking', 1.8481124057791867),
#  ('bourne', 1.8478489358790986),
#  ('lemmon', 1.8458266904983307),
#  ('delightful', 1.8002701588959635),
#  ('flynn', 1.7996646487351682),
#  ('andrews', 1.7764919970972666),
#  ('homer', 1.7692866133759964),
# ...

# %%
print("The pos_nrg_ratio for 'the' = {}".format(pos_neg_ratios['the']))
print("The pos_nrg_ratio for 'amazing' = {}".format(pos_neg_ratios['amazing']))
print("The pos_nrg_ratio for 'terrible' = {}".format(pos_neg_ratios['terrible']))
print("The pos_nrg_ratio for 'was' = {}".format(pos_neg_ratios['was']))
print("The pos_nrg_ratio for 'captivating' = {}".format(pos_neg_ratios['captivating']))
print("The pos_nrg_ratio for 'worse' = {}".format(pos_neg_ratios['worse']))
# Out:
# The pos_nrg_ratio for 'the' = 0.05902269426102881
# The pos_nrg_ratio for 'amazing' = 1.3919815802404802
# The pos_nrg_ratio for 'terrible' = -1.6742829939664696
# The pos_nrg_ratio for 'was' = -0.17007733533863434
# The pos_nrg_ratio for 'captivating' = 1.3862943611198906
# The pos_nrg_ratio for 'worse' = -1.6820086052689358

# %%
# This gives the most frequently used words in a negative review

list(reversed(pos_neg_ratios.most_common()))
# Out:
# [('boll', -4.07781526027089),
#  ('uwe', -3.921875301871158),
#  ('seagal', -3.320250105858192),
#  ('unwatchable', -3.0269848170580955),
#  ('stinker', -2.9876839403711624),
#  ('mst', -2.775383321170797),
#  ('incoherent', -2.7641396677532537),
#  ('unfunny', -2.5545257844967644),
#  ('waste', -2.4907515123361046),
#  ('blah', -2.4475792789485005),
#  ('horrid', -2.371577964480997),
#  ('pointless', -2.345107387713634),
#  ('atrocious', -2.3187369339642556),
#  ('redeeming', -2.2667790015910296),
#  ('prom', -2.2601040980178784),
#  ('drivel', -2.247602958576693),
#  ('lousy', -2.2118080125207054),
#  ('worst', -2.1930856334332267),
#  ('laughable', -2.172468615469592),
#  ('awful', -2.1385076866397488),
#  ('poorly', -2.132613384420701),
#  ('wasting', -2.117815554561451),
#  ('remotely', -2.111046881095167),
#  ('existent', -2.0024805005437076),
#  ('boredom', -1.9241486572738005),
#  ('miserably', -1.921661093801999),
#  ('sucks', -1.9166645809588516),
# ...

# %%
# THis will also give the same result using reverse slicing

pos_neg_ratios.most_common()[:-31:-1]
# Out:
# [('boll', -4.07781526027089),
#  ('uwe', -3.921875301871158),
#  ('seagal', -3.320250105858192),
#  ('unwatchable', -3.0269848170580955),
#  ('stinker', -2.9876839403711624),
#  ('mst', -2.775383321170797),
#  ('incoherent', -2.7641396677532537),
#  ('unfunny', -2.5545257844967644),
#  ('waste', -2.4907515123361046),
#  ('blah', -2.4475792789485005),
#  ('horrid', -2.371577964480997),
#  ('pointless', -2.345107387713634),
#  ('atrocious', -2.3187369339642556),
#  ('redeeming', -2.2667790015910296),
#  ('prom', -2.2601040980178784),
#  ('drivel', -2.247602958576693),
#  ('lousy', -2.2118080125207054),
#  ('worst', -2.1930856334332267),
#  ('laughable', -2.172468615469592),
#  ('awful', -2.1385076866397488),
#  ('poorly', -2.132613384420701),
#  ('wasting', -2.117815554561451),
#  ('remotely', -2.111046881095167),
#  ('existent', -2.0024805005437076),
#  ('boredom', -1.9241486572738005),
#  ('miserably', -1.921661093801999),
#  ('sucks', -1.9166645809588516),
# ...

# %%
total_counts.keys()
# Out:
# dict_keys(['bromwell', 'high', 'is', 'a', 'cartoon', 'comedy', '.', 'it', 'ran', 'at', 'the', 'same', 'time', 'as', 'some', 'other', 'programs', 'about', 'school', 'life', '', 'such', 'teachers', 'my', 'years', 'in', 'teaching', 'profession', 'lead', 'me', 'to', 'believe', 'that', 's', 'satire', 'much', 'closer', 'reality', 'than', 'scramble', 'survive', 'financially', 'insightful', 'students', 'who', 'can', 'see', 'right', 'through', 'their', 'pathetic', 'pomp', 'pettiness', 'of', 'whole', 'situation', 'all', 'remind', 'schools', 'i', 'knew', 'and', 'when', 'saw', 'episode', 'which', 'student', 'repeatedly', 'tried', 'burn', 'down', 'immediately', 'recalled', 'classic', 'line', 'inspector', 'm', 'here', 'sack', 'one', 'your', 'welcome', 'expect', 'many', 'adults', 'age', 'think', 'far', 'fetched', 'what', 'pity', 'isn', 't', 'story', 'man', 'has', 'unnatural', 'feelings', 'for', 'pig', 'starts', 'out', 'with', 'opening', 'scene', 'terrific', 'example', 'absurd', 'formal', 'orchestra
# ...

# %%
vocab = set(total_counts.keys())

# %%
vocab_size = len(vocab)
print(vocab_size)
# Out:
# 74074

# %%
layer_0 = np.zeros((1, vocab_size))

# %%
layer_0
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]])

# %%
layer_0.shape
# Out:
# (1, 74074)

# %%
word2index = {}
for i,word in enumerate(vocab):
    word2index[word] = i
word2index
# Out:
# {'': 0,
#  'reforging': 1,
#  'stubs': 2,
#  'lawson': 3,
#  'herselfthat': 4,
#  'classing': 5,
#  'ep': 6,
#  'gnome': 7,
#  'miserably': 8,
#  'blinded': 9,
#  'conventions': 10,
#  'chosen': 11,
#  'ganged': 12,
#  'tunnah': 13,
#  'dourdan': 14,
#  'nilo': 15,
#  'peaking': 16,
#  'frigging': 17,
#  'easiest': 18,
#  'utrillo': 19,
#  'californication': 20,
#  'ripoff': 21,
#  'schrieber': 22,
#  'zzzzz': 23,
#  'endearment': 24,
#  'window': 25,
#  'montenegrin': 26,
#  'roadmovie': 27,
#  'figured': 28,
#  'souffl': 29,
#  'indifferently': 30,
#  'laser': 31,
#  'diet': 32,
#  'ondrej': 33,
#  'furnished': 34,
#  'tajmahal': 35,
#  'flashforward': 36,
#  'sharpton': 37,
#  'superficically': 38,
#  'doen': 39,
#  'based': 40,
#  'kavanah': 41,
#  'schn': 42,
#  'stringing': 43,
#  'ef': 44,
#  'revising': 45,
#  'metropole': 46,
#  'seizure': 47,
#  'miguel': 48,
#  'primrose': 49,
#  'snchez': 50,
#  'feint': 51,
#  'barter': 52,
#  'compiler': 53,
#  'looms': 54,
# ...

# %%
def update_input_layer(review):
    global layer_0
    layer_0 *= 0
    
    for word in review.split(" "):
        layer_0[0][word2index[word]] += 1

# %%
update_input_layer(reviews[0])
layer_0
# Out:
# array([[18.,  0.,  0., ...,  0.,  0.,  0.]])

# %%
def get_target_for_label(label):
    if(label == 'POSITIVE'):
        return 1
    else:
        return 0

# %%
labels[0]
# Out:
# 'POSITIVE'

# %%
get_target_for_label(labels[1])
# Out:
# 0

# %%
import time
import sys
import numpy as np

class SentimentNetwork:
    def __init__(self, reviews, labels, hidden_nodes = 10, learning_rate = 0.1):
        np.random.seed() # so we have same result each time we run this code
        
        self.pre_process_data(reviews, labels)
        
        self.init_network(len(self.review_vocab), hidden_nodes, 1, learning_rate)
    
    def pre_process_data(self, reviews, labels):
        
        review_vocab = set()
        
        for review in reviews:
            for word in review.split(" "):
                review_vocab.add(word)
                
        self.review_vocab = list(review_vocab)
        
        label_vocab = set()
        
        for label in labels:
            label_vocab.add(label)
            
        self.label_vocab = list(label_vocab)
        
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
        self.word2index = {}
        
        for i, word in enumerate(self.review_vocab):
            self.word2index[word] = i
        self.label2index = {}
        
        for i, label in enumerate(self.label_vocab):
            self.label2index[label] = i
    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes
        
        self.learning_rate = learning_rate
        
        self.weight_0_1 = np.zeros((self.input_nodes, self.hidden_nodes))
        
        self.weight_1_2 = np.random.normal(0.0, self.output_nodes ** -0.5,
                                          (self.hidden_nodes, self.output_nodes))
        self.layer_0 = np.zeros((1, input_nodes))
    
    def update_input_layer(self, review):
        
        self.layer_0 *= 0
        
        for word in review.split(" "):
            
            if(word in self.word2index.keys()):
                self.layer_0[0][self.word2index[word]] += 1
            
    def get_target_for_label(self, label):
        if(label == 'POSITIVE'):
            return 1
        else:
            return 0
    
    def sigmoid(self, x):
        return 1 / (1 + np.exp(-x))
    
    def sigmoid_output_2_derivatives(self, output):
        
        return output * (1 - output)
    
    def train(self, training_reviews, training_labels):
        
        assert(len(training_reviews) == len(training_labels))
        
        correct_so_far = 0 
        
        start = time.time()
        
        
        for i in range(len(training_reviews)):
            
            review = training_reviews[i]
            label = training_labels[i]
            
            
            self.update_input_layer(review)
            
            layer_1 = self.layer_0.dot(self.weight_0_1)
            layer_2 = self.sigmoid(layer_1.dot(self.weight_1_2))
            
            layer_2_error = layer_2 - self.get_target_for_label(label)
            layer_2_delta = layer_2_error * self.sigmoid_output_2_derivatives(layer_2)
            
            layer_1_error = layer_2_delta.dot(self.weight_1_2.T)
            layer_1_delta = layer_1_error
            
            
            self.weight_1_2 -= layer_1.T.dot(layer_2_delta) * self.learning_rate
            self.weight_0_1 -= self.layer_0.T.dot(layer_1_delta) * self.learning_rate
            
            if(layer_2 >= 0.5 and label == "POSITIVE"):
                correct_so_far += 1
            elif(layer_2 < 0.5 and label == "NEGATIVE"):
                correct_so_far += 1
            
            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] \
                             + "% Speed(review/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) \
                             + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")

            if( i % 25000 == 0):
                print(" ")
    def test(self, testing_reviews, testing_labels):
            
        correct = 0
            
        start = time.time()
            
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                
                correct += 1
                    
                elapsed_time = float(time.time() - start)
                reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
                
                sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                                  + "% Speed(review/sec):" + str(reviews_per_second)[0:5] \
                                  + " #Correct:" + str(correct) + " #Tested:" + str(i+1) \
                                  + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")

    def run(self, review):
            
        self.update_input_layer(review.lower())
            
        layer_1 = self.layer_0.dot(self.weight_0_1)
            
        layer_2 = self.sigmoid(layer_1.dot(self.weight_1_2))
            
            
        if(layer_2[0] >= 0.5):
            return "POSITIVE"
        else:
            return "NEGATIVE"

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate = 0.1)
mlp.train(reviews[:-1000], labels[:-1000])
# Out:
# Progress:0.0% Speed(review/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:99.9% Speed(review/sec):54.61 #Correct:12000 #Trained:24000 Training Accuracy:50.0%

# %%
mlp.test(reviews[:-1000], labels[:-1000])
# Out:
# Progress:99.9% Speed(review/sec):398.4 #Correct:12000 #Tested:23999 Testing Accuracy:50.0%

# %%
# reducing the learning rate

mlp = SentimentNetwork(reviews[:-1000], labels[:-1000], learning_rate = 0.01)
mlp.train(reviews[:-1000], labels[:-1000])
# Out:
# Progress:0.0% Speed(review/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:99.9% Speed(review/sec):51.86 #Correct:12014 #Trained:24000 Training Accuracy:50.0%

# %% [markdown]
# ## Improving our Network Efficiency, removing unnecessary multiplications during our forward and backward propagation

# %%
import time
import sys
import numpy as np

class SentimentNetwork:
    def __init__(self, reviews, labels, hidden_nodes = 10, learning_rate = 0.1):
        np.random.seed() # so we have same result each time we run this code
        
        self.pre_process_data(reviews, labels)
        
        self.init_network(len(self.review_vocab), hidden_nodes, 1, learning_rate)
    
    def pre_process_data(self, reviews, labels):
        
        review_vocab = set()
        
        for review in reviews:
            for word in review.split(" "):
                review_vocab.add(word)
                
        self.review_vocab = list(review_vocab)
        
        label_vocab = set()
        
        for label in labels:
            label_vocab.add(label)
            
        self.label_vocab = list(label_vocab)
        
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
        self.word2index = {}
        
        for i, word in enumerate(self.review_vocab):
            self.word2index[word] = i
        self.label2index = {}
        
        for i, label in enumerate(self.label_vocab):
            self.label2index[label] = i
    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes
        
        self.learning_rate = learning_rate
        
        self.weight_0_1 = np.zeros((self.input_nodes, self.hidden_nodes))
        
        self.weight_1_2 = np.random.normal(0.0, self.output_nodes ** -0.5,
                                          (self.hidden_nodes, self.output_nodes))
        self.layer_1 = np.zeros((1, hidden_nodes))
    
    
            
    def get_target_for_label(self, label):
        if(label == 'POSITIVE'):
            return 1
        else:
            return 0
    
    def sigmoid(self, x):
        return 1 / (1 + np.exp(-x))
    
    def sigmoid_output_2_derivatives(self, output):
        
        return output * (1 - output)
    
    def train(self, training_reviews_raw, training_labels):
        # preprocessing training data
        training_reviews = list()
        for review in training_reviews_raw:
            indices = set()
            for word in review.split(" "):
                if(word in self.word2index.keys()):
                    indices.add(self.word2index[word])
            training_reviews.append(list(indices))
            
        assert(len(training_reviews) == len(training_labels))
        
        correct_so_far = 0 
        
        start = time.time()
        
        
        for i in range(len(training_reviews)):
            
            review = training_reviews[i]
            label = training_labels[i]
            
            
            
            
            self.layer_1 *= 0
            
            for index in review:
                self.layer_1 += self.weight_0_1[index]
                
            layer_2 = self.sigmoid(self.layer_1.dot(self.weight_1_2))
            
            layer_2_error = layer_2 - self.get_target_for_label(label)
            layer_2_delta = layer_2_error * self.sigmoid_output_2_derivatives(layer_2)
            
            layer_1_error = layer_2_delta.dot(self.weight_1_2.T)
            layer_1_delta = layer_1_error
            
            
            self.weight_1_2 -= self.layer_1.T.dot(layer_2_delta) * self.learning_rate
            
            for index in review:
                self.weight_0_1[index] -= layer_1_delta[0] * self.learning_rate
           
            
            if(layer_2 >= 0.5 and label == "POSITIVE"):
                correct_so_far += 1
            elif(layer_2 < 0.5 and label == "NEGATIVE"):
                correct_so_far += 1
            
            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] \
                             + "% Speed(review/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) \
                             + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")

            if( i % 25000 == 0):
                print(" ")
    def test(self, testing_reviews, testing_labels):
            
        correct = 0
            
        start = time.time()
            
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                
                correct += 1
                    
                elapsed_time = float(time.time() - start)
                reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
                
                sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                                  + "% Speed(review/sec):" + str(reviews_per_second)[0:5] \
                                  + " #Correct:" + str(correct) + " #Tested:" + str(i+1) \
                                  + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")

    def run(self, review):
            
        self.layer_1 *= 0
        unique_indices = set()
        for word in review.lower().split(" "):
            if word in self.word2index.keys():
                unique_indices.add(self.word2index[word])
        for index in unique_indices:
            self.layer_1 += self.weight_0_1[index]
            
        layer_2 = self.sigmoid(self.layer_1.dot(self.weight_1_2))
            
            
        if(layer_2[0] >= 0.5):
            return "POSITIVE"
        else:
            return "NEGATIVE"

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate = 0.1)
mlp.train(reviews[:-1000], labels[:-1000])
# Out:
# Progress:0.0% Speed(review/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:99.9% Speed(review/sec):282.4 #Correct:20307 #Trained:24000 Training Accuracy:84.6%

# %%
mlp.test(reviews[-1000:], labels[-1000:], learning_rate = 0.1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-9c1bda67e21d> in <module>
# ----> 1 mlp.test(reviews[-1000:], labels[-1000:], learning_rate = 0.1)
#
# TypeError: test() got an unexpected keyword argument 'learning_rate'
